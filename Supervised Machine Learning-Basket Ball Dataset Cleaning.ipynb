# %%
import pandas as pd

# %%
player_df = pd.read_csv('Player data.csv')

# %%
player_df.head()
# Out:
#               Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0   Precious Achiuwa       PF   21     28           408.0             0.599
# 1       Jaylen Adams       PG   24      6            17.0             0.125
# 2       Steven Adams        C   27     27           760.0             0.592
# 3        Bam Adebayo        C   23     26           873.0             0.641
# 4  LaMarcus Aldridge        C   35     18           480.0             0.542
#
#    Threepoint Attempt rate  Free throw attempt rate  Player Efficiency Rating
# 0                    0.000                    0.541                      15.1
# 1                    0.250                    0.000                      -6.9
# 2                      NaN                    0.397                      15.9
# 3                    0.015                    0.469                      22.7
# 4                    0.298                    0.093                      15.2

# %%
player_df.isna().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     2
# Player Efficiency Rating    0
# dtype: int64

# %%
# Print out the information about the DataFrame.
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Player                    497 non-null    object
#  1   Position                  497 non-null    object
#  2   Age                       497 non-null    int64
#  3   Games                     497 non-null    int64
#  4   Minutes Played            495 non-null    float64
#  5   True Shooting(%)          494 non-null    float64
#  6   Threepoint Attempt rate   495 non-null    float64
#  7   Free throw attempt rate   495 non-null    float64
#  8   Player Efficiency Rating  497 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 35.1+ KB

# %%
# Drop rows that have no values.
player_df.dropna(inplace=True, how='all')
player_df.isna().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     2
# Player Efficiency Rating    0
# dtype: int64

# %%
player_df
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
player_df.head(10)
# Out:
#                      Player Position  Age  Games  Minutes Played  \
# 0          Precious Achiuwa       PF   21     28           408.0
# 1              Jaylen Adams       PG   24      6            17.0
# 2              Steven Adams        C   27     27           760.0
# 3               Bam Adebayo        C   23     26           873.0
# 4         LaMarcus Aldridge        C   35     18           480.0
# 5         Ty-Shon Alexander       SG   22      3             8.0
# 6  Nickeil Alexander-Walker       SG   22     23           441.0
# 7             Grayson Allen       SG   25     19           454.0
# 8             Jarrett Allen        C   22     28           734.0
# 9             Jarrett Allen        C   22     12           320.0
#
#    True Shooting(%)  Threepoint Attempt rate  Free throw attempt rate  \
# 0             0.599                    0.000                    0.541
# 1             0.125                    0.250                    0.000
# ...

# %%
player_df.describe()
# Out:
#               Age       Games  Minutes Played  True Shooting(%)  \
# count  497.000000  497.000000      495.000000        494.000000
# mean    25.623742   18.456740      416.492929          0.538939
# std      4.054229    8.311394      297.543620          0.130360
# min     19.000000    1.000000        2.000000          0.000000
# 25%     22.000000   12.000000      127.000000          0.500000
# 50%     25.000000   20.000000      417.000000          0.556000
# 75%     28.000000   26.000000      665.500000          0.607000
# max     37.000000   30.000000     1101.000000          1.500000
#
#        Threepoint Attempt rate  Free throw attempt rate  \
# count               495.000000               495.000000
# mean                  0.406362                 0.274804
# std                   0.234207                 0.270650
# min                   0.000000                 0.000000
# 25%                   0.255000                 0.142000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a list of all column names, except for ID.
cols = list(player_df.iloc[:, 2:])

# Create a 3x5 matrix of subplots.
fig, axes = plt.subplots(3, 5, figsize=(18, 11))

# Create padding around subplots to make the axis labels readable.
fig.tight_layout(pad=2.0)

# Loop over the columns of the DataFrame and create a box plot for each one.
for i in range(len(cols)):
    sns.boxplot(ax=axes[i//5, i%5], y=player_df[cols[i]])

# %%
points_outlier = player_df['True Shooting(%)'].idxmin()
points_outlier
# Out:
# 14

# %%
points_outlier1 = player_df['Player Efficiency Rating'].idxmin()
points_outlier1
# Out:
# 363

# %%
points_outlier2 = player_df['Player Efficiency Rating'].idxmax()
points_outlier2
# Out:
# 81

# %%
points_outlier3 = player_df['True Shooting(%)'].idxmax()
points_outlier3
# Out:
# 125

# %%
player_df.drop(player_df.index[points_outlier], inplace=True)
player_df.drop(player_df.index[points_outlier1], inplace=True)
player_df.drop(player_df.index[points_outlier2], inplace=True)
player_df.drop(player_df.index[points_outlier3], inplace=True)

# %%
player_df.head(10)
# Out:
#                Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0    Precious Achiuwa       PF   21     28           408.0             0.599
# 1        Jaylen Adams       PG   24      6            17.0             0.125
# 2        Steven Adams        C   27     27           760.0             0.592
# 3         Bam Adebayo        C   23     26           873.0             0.641
# 4   LaMarcus Aldridge        C   35     18           480.0             0.542
# 8       Jarrett Allen        C   22     28           734.0             0.695
# 9       Jarrett Allen        C   22     12           320.0             0.730
# 10      Jarrett Allen        C   22     16           414.0               NaN
# 11    Al-Farouq Aminu       PF   30      2            16.0             0.798
# 12      Kyle Anderson       PF   27     24           675.0             0.579
#
#     Threepoint Attempt rate  Free throw attempt rate  Player Efficiency Rating
# ...

# %%
# Create a list of all column names, except for 'ID'.
cols = list(player_df.iloc[:, 2:])

# Define the size for the plots and add padding around them.
fig = plt.figure(figsize=(18, 11))
fig.tight_layout(pad=5.0)

# Loop over the columns in the DataFrame and create a histogram for each one.
for i in range(len(cols)):
    plt.subplot(3, 5, i+1)
    plt.hist(player_df[cols[i]], bins=30)
    plt.title(cols[i])

# %%
# Create a list of all column names, except for 'ID'.
cols = list(player_df.iloc[:, 2:])

# Create a 3x5 matrix of subplots and add padding around them for readability.
fig, axes = plt.subplots(3, 5, figsize=(18, 11))
fig.tight_layout(pad=2.0)

# Loop over the columns of the DataFrame and create a KDE for each one.
for i in range(len(cols)):
    sns.kdeplot(ax=axes[i//5, i%5], data=player_df[cols[i]])

# %%
plt.hist(player_df['Games'], density=True, bins=15)
plt.title('Games histogram')
sns.kdeplot(player_df['Games']);

# %%
plt.hist(player_df['Minutes Played'], density=True, bins=15)
plt.title('Minutes Played histogram')
sns.kdeplot(player_df['Minutes Played']);

# %%
player_df.loc[player_df['Games'] >= 26].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 496
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Player                    140 non-null    object
#  1   Position                  140 non-null    object
#  2   Age                       140 non-null    int64
#  3   Games                     140 non-null    int64
#  4   Minutes Played            140 non-null    float64
#  5   True Shooting(%)          139 non-null    float64
#  6   Threepoint Attempt rate   139 non-null    float64
#  7   Free throw attempt rate   140 non-null    float64
#  8   Player Efficiency Rating  140 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 10.9+ KB

# %%
plt.hist(player_df['True Shooting(%)'], density=True, bins=15)
plt.title('True Shooting(%) histogram')
sns.kdeplot(player_df['True Shooting(%)']);

# %%
df1 = player_df.loc[(player_df['Games'] >= 26) & (player_df['Minutes Played'] >= 0)& (player_df['True Shooting(%)'] >= 0.6)]
df1
# Out:
#                     Player Position  Age  Games  Minutes Played  \
# 3              Bam Adebayo        C   23     26           873.0
# 8            Jarrett Allen        C   22     28           734.0
# 13   Giannis Antetokounmpo       PF   26     27           906.0
# 22           Deandre Ayton        C   22     27           866.0
# 30         Harrison Barnes       PF   28     27           948.0
# 34           Nicolas Batum       SF   32     27           806.0
# 36           Kent Bazemore       SF   31     27           448.0
# 59           Chris Boucher        C   28     28           654.0
# 65           Mikal Bridges       SF   24     27           898.0
# 98            John Collins       PF   23     28           884.0
# 108          Stephen Curry       PG   32     29           987.0
# 136         Derrick Favors        C   29     27           444.0
# 143            Bryn Forbes       SG   27     28           514.0
# 161            Rudy Gobert        C   28     29           878.0
# ...

# %%
# Initialize the list to house the player data.
player_df["id"] = player_df.index + 1
pop_list = []

for id in player_df['id']:
    if id in df1['id']:
        pop_list.append('tune_squad'+str(id%sum(df1.id)))
    else:
        pop_list.append('player'+str(id))
pop_list
# Out:
# ['player1',
#  'player2',
#  'tune_squad3',
#  'player4',
#  'player5',
#  'player9',
#  'player10',
#  'player11',
#  'player12',
#  'tune_squad13',
#  'player14',
#  'player15',
#  'player16',
#  'player17',
#  'player21',
#  'tune_squad22',
#  'player23',
#  'player24',
#  'player25',
#  'player26',
#  'player27',
#  'player28',
#  'player29',
#  'tune_squad30',
#  'player31',
#  'player32',
#  'player33',
#  'tune_squad34',
#  'player35',
#  'tune_squad36',
#  'player37',
#  'player38',
#  'player39',
#  'player40',
#  'player41',
#  'player42',
#  'player43',
#  'player44',
#  'player45',
#  'player46',
#  'player47',
#  'player48',
#  'player49',
#  'player50',
#  'player51',
#  'player52',
#  'player53',
#  'player54',
#  'player55',
#  'player56',
#  'player57',
#  'player58',
#  'tune_squad59',
#  'player60',
#  'player61',
#  'player62',
#  'player63',
#  'player64',
#  'tune_squad65',
#  'player66',
#  'player67',
#  'player68',
#  'player69',
#  'player70',
# ...

# %%
# Assign this list as the values for the new player column in the DataFrame.
player_df['player'] = pop_list
player_df.head()
# Out:
#               Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0   Precious Achiuwa       PF   21     28           408.0             0.599
# 1       Jaylen Adams       PG   24      6            17.0             0.125
# 2       Steven Adams        C   27     27           760.0             0.592
# 3        Bam Adebayo        C   23     26           873.0             0.641
# 4  LaMarcus Aldridge        C   35     18           480.0             0.542
#
#    Threepoint Attempt rate  Free throw attempt rate  Player Efficiency Rating  \
# 0                    0.000                    0.541                      15.1
# 1                    0.250                    0.000                      -6.9
# 2                      NaN                    0.397                      15.9
# 3                    0.015                    0.469                      22.7
# 4                    0.298                    0.093                      15.2
#
#    id       player
# 0   1      player1
# ...

# %%
# Create list of all DataFrame column names but the last one.
column_list = list(player_df.iloc[:, :-1])

# Make player the second item in the list.
column_list.insert(1, 'player')

# Reassign the columns in the player_df DataFrame in this new order.
player_df = player_df[column_list]

# Verify that the columns are ordered the way you expect.
player_df.head()
# Out:
#               Player       player Position  Age  Games  Minutes Played  \
# 0   Precious Achiuwa      player1       PF   21     28           408.0
# 1       Jaylen Adams      player2       PG   24      6            17.0
# 2       Steven Adams  tune_squad3        C   27     27           760.0
# 3        Bam Adebayo      player4        C   23     26           873.0
# 4  LaMarcus Aldridge      player5        C   35     18           480.0
#
#    True Shooting(%)  Threepoint Attempt rate  Free throw attempt rate  \
# 0             0.599                    0.000                    0.541
# 1             0.125                    0.250                    0.000
# 2             0.592                      NaN                    0.397
# 3             0.641                    0.015                    0.469
# 4             0.542                    0.298                    0.093
#
#    Player Efficiency Rating  id
# 0                      15.1   1
# 1                      -6.9   2
# ...

# %%
player_df.isna().sum()
# Out:
# Player                      0
# player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     1
# Player Efficiency Rating    0
# id                          0
# dtype: int64

# %%
plt.hist(player_df['Minutes Played'], density=True, bins=15)
plt.title('Minutes Played histogram')
sns.kdeplot(player_df['Minutes Played']);

# %%
plt.hist(player_df['True Shooting(%)'], density=True, bins=15)
plt.title('True Shooting(%) histogram')
sns.kdeplot(player_df['True Shooting(%)']);

# %%
plt.hist(player_df['Threepoint Attempt rate'], density=True, bins=15)
plt.title('Threepoint Attempt rate histogram')
sns.kdeplot(player_df['Threepoint Attempt rate']);

# %%
plt.hist(player_df['Free throw attempt rate'], density=True, bins=15)
plt.title('Free throw attempt rate  histogram')
sns.kdeplot(player_df['Free throw attempt rate']);

# %%
player_df[['Minutes Played','True Shooting(%)','Threepoint Attempt rate','Free throw attempt rate']] = player_df[['Minutes Played','True Shooting(%)','Threepoint Attempt rate','Free throw attempt rate']].fillna(value=player_df[['Minutes Played','True Shooting(%)','Threepoint Attempt rate','Free throw attempt rate']].mean())

player_df.isna().sum()
# Out:
# Player                      0
# player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              0
# True Shooting(%)            0
# Threepoint Attempt rate     0
# Free throw attempt rate     0
# Player Efficiency Rating    0
# id                          0
# dtype: int64

# %%
player_df
# Out:
#                 Player         player Position  Age  Games  Minutes Played  \
# 0     Precious Achiuwa        player1       PF   21     28           408.0
# 1         Jaylen Adams        player2       PG   24      6            17.0
# 2         Steven Adams    tune_squad3        C   27     27           760.0
# 3          Bam Adebayo        player4        C   23     26           873.0
# 4    LaMarcus Aldridge        player5        C   35     18           480.0
# ..                 ...            ...      ...  ...    ...             ...
# 492       Delon Wright      player493       SG   28     28           823.0
# 493     Thaddeus Young      player494       PF   32     23           592.0
# 494         Trae Young      player495       PG   22     26           901.0
# 495        Cody Zeller  tune_squad496        C   28     15           361.0
# 496        Ivica Zubac      player497        C   23     30           586.0
#
# ...
